# %% [markdown]
# ## CT and RT Structure data Pre-processing for multi-label survival prediction using planing CT

# %% [markdown]
# ### 1. dicom to nii conversion

# %%
from dcmrtstruct2nii import dcmrtstruct2nii, list_rt_structs
import os, sys, glob

from tqdm.notebook import tqdm
from time import sleep

# %%
oriPath = '../../data/OPC_Radiomics/OPC-Radiomics/' # can be download at https://wiki.cancerimagingarchive.net/pages/viewpage.action?pageId=33948764
# we have download it to  T:\Physics_Research\LABS\LAB_Wang_Zhang\Data\OPC_Radiomics
patients = os.listdir(oriPath)

savePath = '../../data/OPC_Radiomics/OPC-Radiomics-Nii/' # wherever you want to save the Nii files
if not os.path.exists(savePath):
   os.makedirs(savePath)

# %%
# for i in tqdm(range(len(patients))):
#     sleep(0.01)
    # p = patients[i]
for p in patients:
    folder = os.listdir(os.path.join(oriPath, p))
    if len(folder)==0:
        print('!!!!! No data for ',p)
        continue
    subFolder = os.listdir(os.path.join(oriPath, p, folder[0]))
    if len(subFolder)<2:
        print('!!!!! No engough data for ',p)
        continue
    pSavePath = os.path.join(savePath,p)

    RTfile = None
    imagePath = None

    for s in subFolder:
        if len(os.listdir(os.path.join(oriPath, p, folder[0], s)))==1:
            RTfile = glob.glob(os.path.join(oriPath, p, folder[0], s,'00000*'))
        else:
            imagePath = os.path.join(oriPath, p, folder[0], s)
    # dcmrtstruct2nii(RTfile[0],imagePath,pSavePath)
    try:
        dcmrtstruct2nii(RTfile[0],imagePath,pSavePath)
        print('Img and RTStructure Niis Generated for ', p)
    except:
        print('!!!!!!!!!!!!!!! Something wrong with ', p)

    # print(RTfile[0])
    # print(imagePath)
    # print(pSavePath)
# Out:
# !!!!! No engough data for  OPC-00312
# Img and RTStructure Niis Generated for  OPC-00260
# Img and RTStructure Niis Generated for  OPC-00182
# Img and RTStructure Niis Generated for  OPC-00001
# Img and RTStructure Niis Generated for  OPC-00374
# Img and RTStructure Niis Generated for  OPC-00317
# Img and RTStructure Niis Generated for  OPC-00360
# Img and RTStructure Niis Generated for  OPC-00517
# Img and RTStructure Niis Generated for  OPC-00187
# Img and RTStructure Niis Generated for  OPC-00506
# Img and RTStructure Niis Generated for  OPC-00313
# Img and RTStructure Niis Generated for  OPC-00212
# Img and RTStructure Niis Generated for  OPC-00305
# Img and RTStructure Niis Generated for  OPC-00218
# Img and RTStructure Niis Generated for  OPC-00419
# Img and RTStructure Niis Generated for  OPC-00405
# Img and RTStructure Niis Generated for  OPC-00008
# Img and RTStructure Niis Generated for  OPC-00325
# Img and RTStructure Niis Generated for  OPC-00063
# Img and RTStructure Niis Generated for  OPC-00281
# Img and RTStructure Niis Generated for  OPC-00571
# Img and RTStructure Niis Generated for  OPC-00306
# Img and RTStructure Niis Generated for  OPC-00092
# Img and RTStructure Niis Generated for  OPC-00341
# Img and RTStructure Niis Generated for  OPC-00447
# Img and RTStructure Niis Generated for  OPC-00150
# Img and RTStructure Niis Generated for  OPC-00032
# Img and RTStructure Niis Generated for  OPC-00018
# Img and RTStructure Niis Generated for  OPC-00393
# Img and RTStructure Niis Generated for  OPC-00307
# Img and RTStructure Niis Generated for  OPC-00432
# Img and RTStructure Niis Generated for  OPC-00501
# Img and RTStructure Niis Generated for  OPC-00283
# Img and RTStructure Niis Generated for  OPC-00461
# Img and RTStructure Niis Generated for  OPC-00155
# Img and RTStructure Niis Generated for  OPC-00073
# Img and RTStructure Niis Generated for  OPC-00066
# Img and RTStructure Niis Generated for  OPC-00246
# Img and RTStructure Niis Generated for  OPC-00533
# Img and RTStructure Niis Generated for  OPC-00457
# Img and RTStructure Niis Generated for  OPC-00594
# Img and RTStructure Niis Generated for  OPC-00258
# Img and RTStructure Niis Generated for  OPC-00213
# Img and RTStructure Niis Generated for  OPC-00450
# Img and RTStructure Niis Generated for  OPC-00200
# Img and RTStructure Niis Generated for  OPC-00347
# Img and RTStructure Niis Generated for  OPC-00508
# Img and RTStructure Niis Generated for  OPC-00451
# Img and RTStructure Niis Generated for  OPC-00274
# Img and RTStructure Niis Generated for  OPC-00152
# Img and RTStructure Niis Generated for  OPC-00479
# Img and RTStructure Niis Generated for  OPC-00245
# Img and RTStructure Niis Generated for  OPC-00342
# Img and RTStructure Niis Generated for  OPC-00345
# Img and RTStructure Niis Generated for  OPC-00037
# Img and RTStructure Niis Generated for  OPC-00605
# Img and RTStructure Niis Generated for  OPC-00135
# Img and RTStructure Niis Generated for  OPC-00141
# Img and RTStructure Niis Generated for  OPC-00059
# Img and RTStructure Niis Generated for  OPC-00602
# Img and RTStructure Niis Generated for  OPC-00475
# Img and RTStructure Niis Generated for  OPC-00466
# Img and RTStructure Niis Generated for  OPC-00471
# Img and RTStructure Niis Generated for  OPC-00584
# Img and RTStructure Niis Generated for  OPC-00198
# Img and RTStructure Niis Generated for  OPC-00123
# Img and RTStructure Niis Generated for  OPC-00120
# !!!!! No engough data for  OPC-00231
# Img and RTStructure Niis Generated for  OPC-00398
# Img and RTStructure Niis Generated for  OPC-00075
# Img and RTStructure Niis Generated for  OPC-00087
# Img and RTStructure Niis Generated for  OPC-00413
# Img and RTStructure Niis Generated for  OPC-00430
# Img and RTStructure Niis Generated for  OPC-00143
# Img and RTStructure Niis Generated for  OPC-00299
# Img and RTStructure Niis Generated for  OPC-00550
# Img and RTStructure Niis Generated for  OPC-00055
# Img and RTStructure Niis Generated for  OPC-00495
# Img and RTStructure Niis Generated for  OPC-00558
# Img and RTStructure Niis Generated for  OPC-00494
# Img and RTStructure Niis Generated for  OPC-00101
# Img and RTStructure Niis Generated for  OPC-00202
# Img and RTStructure Niis Generated for  OPC-00356
# Img and RTStructure Niis Generated for  OPC-00103
# Img and RTStructure Niis Generated for  OPC-00070
# Img and RTStructure Niis Generated for  OPC-00168
# Img and RTStructure Niis Generated for  OPC-00477
# Img and RTStructure Niis Generated for  OPC-00352
# Img and RTStructure Niis Generated for  OPC-00191
# Img and RTStructure Niis Generated for  OPC-00340
# Img and RTStructure Niis Generated for  OPC-00566
# Img and RTStructure Niis Generated for  OPC-00346
# Img and RTStructure Niis Generated for  OPC-00253
# Img and RTStructure Niis Generated for  OPC-00185
# Img and RTStructure Niis Generated for  OPC-00301
# Img and RTStructure Niis Generated for  OPC-00510
# Img and RTStructure Niis Generated for  OPC-00395
# Img and RTStructure Niis Generated for  OPC-00572
# Img and RTStructure Niis Generated for  OPC-00088
# Img and RTStructure Niis Generated for  OPC-00551
# Img and RTStructure Niis Generated for  OPC-00248
# Img and RTStructure Niis Generated for  OPC-00330
# Img and RTStructure Niis Generated for  OPC-00194
# Img and RTStructure Niis Generated for  OPC-00314
# Img and RTStructure Niis Generated for  OPC-00220
# Img and RTStructure Niis Generated for  OPC-00383
# Img and RTStructure Niis Generated for  OPC-00372
# Img and RTStructure Niis Generated for  OPC-00188
# Img and RTStructure Niis Generated for  OPC-00107
# Img and RTStructure Niis Generated for  OPC-00369
# Img and RTStructure Niis Generated for  OPC-00298
# Img and RTStructure Niis Generated for  OPC-00526
# Img and RTStructure Niis Generated for  OPC-00029
# Img and RTStructure Niis Generated for  OPC-00233
# Img and RTStructure Niis Generated for  OPC-00025
# Img and RTStructure Niis Generated for  OPC-00020
# Img and RTStructure Niis Generated for  OPC-00586
# Img and RTStructure Niis Generated for  OPC-00240
# Img and RTStructure Niis Generated for  OPC-00513
# Img and RTStructure Niis Generated for  OPC-00394
# Img and RTStructure Niis Generated for  OPC-00412
# Img and RTStructure Niis Generated for  OPC-00216
# Img and RTStructure Niis Generated for  OPC-00051
# Img and RTStructure Niis Generated for  OPC-00499
# Img and RTStructure Niis Generated for  OPC-00142
# Img and RTStructure Niis Generated for  OPC-00193
# Img and RTStructure Niis Generated for  OPC-00121
# Img and RTStructure Niis Generated for  OPC-00060
# Img and RTStructure Niis Generated for  OPC-00514
# Img and RTStructure Niis Generated for  OPC-00596
# Img and RTStructure Niis Generated for  OPC-00156
# Img and RTStructure Niis Generated for  OPC-00279
# Img and RTStructure Niis Generated for  OPC-00252
# Img and RTStructure Niis Generated for  OPC-00106
# Img and RTStructure Niis Generated for  OPC-00548
# Img and RTStructure Niis Generated for  OPC-00421
# Img and RTStructure Niis Generated for  OPC-00199
# Img and RTStructure Niis Generated for  OPC-00534
# Img and RTStructure Niis Generated for  OPC-00591
# Img and RTStructure Niis Generated for  OPC-00402
# Img and RTStructure Niis Generated for  OPC-00593
# Img and RTStructure Niis Generated for  OPC-00219
# Img and RTStructure Niis Generated for  OPC-00167
# Img and RTStructure Niis Generated for  OPC-00326
# Img and RTStructure Niis Generated for  OPC-00036
# Img and RTStructure Niis Generated for  OPC-00056
# Img and RTStructure Niis Generated for  OPC-00268
# Img and RTStructure Niis Generated for  OPC-00319
# Img and RTStructure Niis Generated for  OPC-00067
# Img and RTStructure Niis Generated for  OPC-00585
# Img and RTStructure Niis Generated for  OPC-00030
# Img and RTStructure Niis Generated for  OPC-00563
# Img and RTStructure Niis Generated for  OPC-00084
# Img and RTStructure Niis Generated for  OPC-00531
# Img and RTStructure Niis Generated for  OPC-00229
# Img and RTStructure Niis Generated for  OPC-00096
# Img and RTStructure Niis Generated for  OPC-00598
# Img and RTStructure Niis Generated for  OPC-00492
# Img and RTStructure Niis Generated for  OPC-00046
# Img and RTStructure Niis Generated for  OPC-00359
# Img and RTStructure Niis Generated for  OPC-00463
# Img and RTStructure Niis Generated for  OPC-00308
# Img and RTStructure Niis Generated for  OPC-00062
# Img and RTStructure Niis Generated for  OPC-00235
# Img and RTStructure Niis Generated for  OPC-00124
# Img and RTStructure Niis Generated for  OPC-00186
# Img and RTStructure Niis Generated for  OPC-00570
# Img and RTStructure Niis Generated for  OPC-00538
# Img and RTStructure Niis Generated for  OPC-00153
# Img and RTStructure Niis Generated for  OPC-00582
# Img and RTStructure Niis Generated for  OPC-00370
# Img and RTStructure Niis Generated for  OPC-00411
# Img and RTStructure Niis Generated for  OPC-00323
# Img and RTStructure Niis Generated for  OPC-00573
# Img and RTStructure Niis Generated for  OPC-00357
# Img and RTStructure Niis Generated for  OPC-00392
# Img and RTStructure Niis Generated for  OPC-00476
# Img and RTStructure Niis Generated for  OPC-00131
# Img and RTStructure Niis Generated for  OPC-00006
# Img and RTStructure Niis Generated for  OPC-00587
# Img and RTStructure Niis Generated for  OPC-00057
# Img and RTStructure Niis Generated for  OPC-00454
# Img and RTStructure Niis Generated for  OPC-00038
# Img and RTStructure Niis Generated for  OPC-00569
# Img and RTStructure Niis Generated for  OPC-00321
# Img and RTStructure Niis Generated for  OPC-00344
# Img and RTStructure Niis Generated for  OPC-00251
# Img and RTStructure Niis Generated for  OPC-00004
# Img and RTStructure Niis Generated for  OPC-00404
# Img and RTStructure Niis Generated for  OPC-00040
# Img and RTStructure Niis Generated for  OPC-00409
# Img and RTStructure Niis Generated for  OPC-00098
# Img and RTStructure Niis Generated for  OPC-00420
# Img and RTStructure Niis Generated for  OPC-00089
# Img and RTStructure Niis Generated for  OPC-00116
# Img and RTStructure Niis Generated for  OPC-00065
# Img and RTStructure Niis Generated for  OPC-00138
# Img and RTStructure Niis Generated for  OPC-00226
# Img and RTStructure Niis Generated for  OPC-00054
# Img and RTStructure Niis Generated for  OPC-00382
# Img and RTStructure Niis Generated for  OPC-00090
# Img and RTStructure Niis Generated for  OPC-00368
# Img and RTStructure Niis Generated for  OPC-00331
# Img and RTStructure Niis Generated for  OPC-00237
# Img and RTStructure Niis Generated for  OPC-00403
# Img and RTStructure Niis Generated for  OPC-00315
# Img and RTStructure Niis Generated for  OPC-00174
# Img and RTStructure Niis Generated for  OPC-00351
# Img and RTStructure Niis Generated for  OPC-00310
# Img and RTStructure Niis Generated for  OPC-00276
# Img and RTStructure Niis Generated for  OPC-00126
# Img and RTStructure Niis Generated for  OPC-00039
# Img and RTStructure Niis Generated for  OPC-00337
# Img and RTStructure Niis Generated for  OPC-00487
# Img and RTStructure Niis Generated for  OPC-00009
# Img and RTStructure Niis Generated for  OPC-00044
# Img and RTStructure Niis Generated for  OPC-00520
# Img and RTStructure Niis Generated for  OPC-00291
# Img and RTStructure Niis Generated for  OPC-00358
# Img and RTStructure Niis Generated for  OPC-00179
# Img and RTStructure Niis Generated for  OPC-00468
# Img and RTStructure Niis Generated for  OPC-00149
# Img and RTStructure Niis Generated for  OPC-00433
# Img and RTStructure Niis Generated for  OPC-00072
# Img and RTStructure Niis Generated for  OPC-00017
# Img and RTStructure Niis Generated for  OPC-00287
# Img and RTStructure Niis Generated for  OPC-00561
# !!!!! No engough data for  OPC-00071
# Img and RTStructure Niis Generated for  OPC-00232
# Img and RTStructure Niis Generated for  OPC-00601
# Img and RTStructure Niis Generated for  OPC-00422
# Img and RTStructure Niis Generated for  OPC-00078
# Img and RTStructure Niis Generated for  OPC-00127
# Img and RTStructure Niis Generated for  OPC-00418
# Img and RTStructure Niis Generated for  OPC-00333
# Img and RTStructure Niis Generated for  OPC-00410
# Img and RTStructure Niis Generated for  OPC-00442
# Img and RTStructure Niis Generated for  OPC-00500
# Img and RTStructure Niis Generated for  OPC-00557
# Img and RTStructure Niis Generated for  OPC-00061
# Img and RTStructure Niis Generated for  OPC-00021
# Img and RTStructure Niis Generated for  OPC-00434
# Img and RTStructure Niis Generated for  OPC-00362
# Img and RTStructure Niis Generated for  OPC-00462
# Img and RTStructure Niis Generated for  OPC-00284
# Img and RTStructure Niis Generated for  OPC-00443
# Img and RTStructure Niis Generated for  OPC-00540
# Img and RTStructure Niis Generated for  OPC-00578
# Img and RTStructure Niis Generated for  OPC-00316
# Img and RTStructure Niis Generated for  OPC-00011
# Img and RTStructure Niis Generated for  OPC-00518
# Img and RTStructure Niis Generated for  OPC-00111
# Img and RTStructure Niis Generated for  OPC-00016
# Img and RTStructure Niis Generated for  OPC-00429
# Img and RTStructure Niis Generated for  OPC-00604
# Img and RTStructure Niis Generated for  OPC-00064
# Img and RTStructure Niis Generated for  OPC-00575
# Img and RTStructure Niis Generated for  OPC-00453
# Img and RTStructure Niis Generated for  OPC-00436
# Img and RTStructure Niis Generated for  OPC-00250
# Img and RTStructure Niis Generated for  OPC-00318
# Img and RTStructure Niis Generated for  OPC-00296
# Img and RTStructure Niis Generated for  OPC-00589
# Img and RTStructure Niis Generated for  OPC-00257
# Img and RTStructure Niis Generated for  OPC-00269
# Img and RTStructure Niis Generated for  OPC-00034
# Img and RTStructure Niis Generated for  OPC-00304
# Img and RTStructure Niis Generated for  OPC-00539
# Img and RTStructure Niis Generated for  OPC-00217
# Img and RTStructure Niis Generated for  OPC-00504
# Img and RTStructure Niis Generated for  OPC-00151
# Img and RTStructure Niis Generated for  OPC-00523
# Img and RTStructure Niis Generated for  OPC-00161
# Img and RTStructure Niis Generated for  OPC-00426
# Img and RTStructure Niis Generated for  OPC-00554
# Img and RTStructure Niis Generated for  OPC-00171
# Img and RTStructure Niis Generated for  OPC-00005
# Img and RTStructure Niis Generated for  OPC-00227
# Img and RTStructure Niis Generated for  OPC-00536
# Img and RTStructure Niis Generated for  OPC-00093
# Img and RTStructure Niis Generated for  OPC-00222
# Img and RTStructure Niis Generated for  OPC-00332
# Img and RTStructure Niis Generated for  OPC-00381
# Img and RTStructure Niis Generated for  OPC-00180
# Img and RTStructure Niis Generated for  OPC-00580
# Img and RTStructure Niis Generated for  OPC-00275
# Img and RTStructure Niis Generated for  OPC-00208
# Img and RTStructure Niis Generated for  OPC-00427
# Img and RTStructure Niis Generated for  OPC-00592
# Img and RTStructure Niis Generated for  OPC-00416
# Img and RTStructure Niis Generated for  OPC-00562
# Img and RTStructure Niis Generated for  OPC-00384
# Img and RTStructure Niis Generated for  OPC-00459
# Img and RTStructure Niis Generated for  OPC-00137
# Img and RTStructure Niis Generated for  OPC-00215
# Img and RTStructure Niis Generated for  OPC-00552
# Img and RTStructure Niis Generated for  OPC-00242
# Img and RTStructure Niis Generated for  OPC-00273
# Img and RTStructure Niis Generated for  OPC-00154
# Img and RTStructure Niis Generated for  OPC-00105
# Img and RTStructure Niis Generated for  OPC-00080
# Img and RTStructure Niis Generated for  OPC-00389
# Img and RTStructure Niis Generated for  OPC-00355
# Img and RTStructure Niis Generated for  OPC-00144
# Img and RTStructure Niis Generated for  OPC-00085
# Img and RTStructure Niis Generated for  OPC-00230
# Img and RTStructure Niis Generated for  OPC-00537
# Img and RTStructure Niis Generated for  OPC-00082
# Img and RTStructure Niis Generated for  OPC-00339
# Img and RTStructure Niis Generated for  OPC-00425
# Img and RTStructure Niis Generated for  OPC-00503
# Img and RTStructure Niis Generated for  OPC-00397
# Img and RTStructure Niis Generated for  OPC-00172
# Img and RTStructure Niis Generated for  OPC-00265
# Img and RTStructure Niis Generated for  OPC-00348
# Img and RTStructure Niis Generated for  OPC-00234
# Img and RTStructure Niis Generated for  OPC-00083
# Img and RTStructure Niis Generated for  OPC-00509
# Img and RTStructure Niis Generated for  OPC-00277
# Img and RTStructure Niis Generated for  OPC-00079
# Img and RTStructure Niis Generated for  OPC-00210
# Img and RTStructure Niis Generated for  OPC-00603
# Img and RTStructure Niis Generated for  OPC-00097
# Img and RTStructure Niis Generated for  OPC-00125
# Img and RTStructure Niis Generated for  OPC-00214
# Img and RTStructure Niis Generated for  OPC-00225
# Img and RTStructure Niis Generated for  OPC-00132
# Img and RTStructure Niis Generated for  OPC-00373
# Img and RTStructure Niis Generated for  OPC-00074
# Img and RTStructure Niis Generated for  OPC-00481
# Img and RTStructure Niis Generated for  OPC-00076
# Img and RTStructure Niis Generated for  OPC-00166
# Img and RTStructure Niis Generated for  OPC-00007
# Img and RTStructure Niis Generated for  OPC-00417
# Img and RTStructure Niis Generated for  OPC-00272
# Img and RTStructure Niis Generated for  OPC-00375
# Img and RTStructure Niis Generated for  OPC-00464
# Img and RTStructure Niis Generated for  OPC-00521
# Img and RTStructure Niis Generated for  OPC-00282
# Img and RTStructure Niis Generated for  OPC-00190
# Img and RTStructure Niis Generated for  OPC-00195
# Img and RTStructure Niis Generated for  OPC-00535
# Img and RTStructure Niis Generated for  OPC-00498
# Img and RTStructure Niis Generated for  OPC-00002
# Img and RTStructure Niis Generated for  OPC-00267
# Img and RTStructure Niis Generated for  OPC-00295
# Img and RTStructure Niis Generated for  OPC-00565
# Img and RTStructure Niis Generated for  OPC-00247
# Img and RTStructure Niis Generated for  OPC-00472
# Img and RTStructure Niis Generated for  OPC-00181
# Img and RTStructure Niis Generated for  OPC-00160
# Img and RTStructure Niis Generated for  OPC-00196
# Img and RTStructure Niis Generated for  OPC-00470
# !!!!! No engough data for  OPC-00205
# Img and RTStructure Niis Generated for  OPC-00163
# Img and RTStructure Niis Generated for  OPC-00047
# Img and RTStructure Niis Generated for  OPC-00197
# Img and RTStructure Niis Generated for  OPC-00049
# Img and RTStructure Niis Generated for  OPC-00327
# Img and RTStructure Niis Generated for  OPC-00255
# Img and RTStructure Niis Generated for  OPC-00012
# Img and RTStructure Niis Generated for  OPC-00053
# Img and RTStructure Niis Generated for  OPC-00140
# Img and RTStructure Niis Generated for  OPC-00189
# Img and RTStructure Niis Generated for  OPC-00157
# Img and RTStructure Niis Generated for  OPC-00423
# Img and RTStructure Niis Generated for  OPC-00524
# Img and RTStructure Niis Generated for  OPC-00146
# Img and RTStructure Niis Generated for  OPC-00045
# Img and RTStructure Niis Generated for  OPC-00388
# Img and RTStructure Niis Generated for  OPC-00441
# Img and RTStructure Niis Generated for  OPC-00184
# Img and RTStructure Niis Generated for  OPC-00300
# Img and RTStructure Niis Generated for  OPC-00496
# Img and RTStructure Niis Generated for  OPC-00042
# Img and RTStructure Niis Generated for  OPC-00564
# Img and RTStructure Niis Generated for  OPC-00460
# Img and RTStructure Niis Generated for  OPC-00515
# Img and RTStructure Niis Generated for  OPC-00003
# Img and RTStructure Niis Generated for  OPC-00112
# Img and RTStructure Niis Generated for  OPC-00177
# Img and RTStructure Niis Generated for  OPC-00069
# Img and RTStructure Niis Generated for  OPC-00364
# Img and RTStructure Niis Generated for  OPC-00567
# Img and RTStructure Niis Generated for  OPC-00350
# Img and RTStructure Niis Generated for  OPC-00133
# Img and RTStructure Niis Generated for  OPC-00170
# Img and RTStructure Niis Generated for  OPC-00458
# Img and RTStructure Niis Generated for  OPC-00577
# Img and RTStructure Niis Generated for  OPC-00128
# Img and RTStructure Niis Generated for  OPC-00311
# Img and RTStructure Niis Generated for  OPC-00467
# Img and RTStructure Niis Generated for  OPC-00448
# Img and RTStructure Niis Generated for  OPC-00104
# Img and RTStructure Niis Generated for  OPC-00400
# Img and RTStructure Niis Generated for  OPC-00201
# Img and RTStructure Niis Generated for  OPC-00367
# Img and RTStructure Niis Generated for  OPC-00309
# Img and RTStructure Niis Generated for  OPC-00041
# Img and RTStructure Niis Generated for  OPC-00173
# Img and RTStructure Niis Generated for  OPC-00263
# Img and RTStructure Niis Generated for  OPC-00322
# !!!!! No engough data for  OPC-00597
# Img and RTStructure Niis Generated for  OPC-00378
# Img and RTStructure Niis Generated for  OPC-00431
# Img and RTStructure Niis Generated for  OPC-00203
# Img and RTStructure Niis Generated for  OPC-00290
# Img and RTStructure Niis Generated for  OPC-00086
# Img and RTStructure Niis Generated for  OPC-00033
# Img and RTStructure Niis Generated for  OPC-00110
# Img and RTStructure Niis Generated for  OPC-00473
# Img and RTStructure Niis Generated for  OPC-00293
# Img and RTStructure Niis Generated for  OPC-00545
# Img and RTStructure Niis Generated for  OPC-00406
# Img and RTStructure Niis Generated for  OPC-00490
# Img and RTStructure Niis Generated for  OPC-00262
# Img and RTStructure Niis Generated for  OPC-00525
# Img and RTStructure Niis Generated for  OPC-00437
# Img and RTStructure Niis Generated for  OPC-00555
# Img and RTStructure Niis Generated for  OPC-00292
# Img and RTStructure Niis Generated for  OPC-00204
# Img and RTStructure Niis Generated for  OPC-00286
# Img and RTStructure Niis Generated for  OPC-00023
# Img and RTStructure Niis Generated for  OPC-00239
# Img and RTStructure Niis Generated for  OPC-00165
# Img and RTStructure Niis Generated for  OPC-00440
# Img and RTStructure Niis Generated for  OPC-00527
# Img and RTStructure Niis Generated for  OPC-00363
# Img and RTStructure Niis Generated for  OPC-00115
# Img and RTStructure Niis Generated for  OPC-00320
# Img and RTStructure Niis Generated for  OPC-00559
# Img and RTStructure Niis Generated for  OPC-00145
# Img and RTStructure Niis Generated for  OPC-00574
# Img and RTStructure Niis Generated for  OPC-00288
# Img and RTStructure Niis Generated for  OPC-00280
# Img and RTStructure Niis Generated for  OPC-00428
# Img and RTStructure Niis Generated for  OPC-00507
# Img and RTStructure Niis Generated for  OPC-00366
# Img and RTStructure Niis Generated for  OPC-00482
# Img and RTStructure Niis Generated for  OPC-00599
# Img and RTStructure Niis Generated for  OPC-00294
# Img and RTStructure Niis Generated for  OPC-00249
# Img and RTStructure Niis Generated for  OPC-00139
# !!!!! No engough data for  OPC-00445
# Img and RTStructure Niis Generated for  OPC-00485
# Img and RTStructure Niis Generated for  OPC-00519
# Img and RTStructure Niis Generated for  OPC-00159
# Img and RTStructure Niis Generated for  OPC-00148
# Img and RTStructure Niis Generated for  OPC-00241
# Img and RTStructure Niis Generated for  OPC-00361
# Img and RTStructure Niis Generated for  OPC-00532
# Img and RTStructure Niis Generated for  OPC-00386
# Img and RTStructure Niis Generated for  OPC-00456
# Img and RTStructure Niis Generated for  OPC-00556
# Img and RTStructure Niis Generated for  OPC-00164
# Img and RTStructure Niis Generated for  OPC-00099
# Img and RTStructure Niis Generated for  OPC-00600
# Img and RTStructure Niis Generated for  OPC-00391
# Img and RTStructure Niis Generated for  OPC-00595
# Img and RTStructure Niis Generated for  OPC-00238
# Img and RTStructure Niis Generated for  OPC-00130
# Img and RTStructure Niis Generated for  OPC-00415
# Img and RTStructure Niis Generated for  OPC-00266
# Img and RTStructure Niis Generated for  OPC-00377
# Img and RTStructure Niis Generated for  OPC-00243
# Img and RTStructure Niis Generated for  OPC-00169
# Img and RTStructure Niis Generated for  OPC-00489
# Img and RTStructure Niis Generated for  OPC-00543
# Img and RTStructure Niis Generated for  OPC-00576
# Img and RTStructure Niis Generated for  OPC-00505
# Img and RTStructure Niis Generated for  OPC-00376
# Img and RTStructure Niis Generated for  OPC-00100
# Img and RTStructure Niis Generated for  OPC-00259
# Img and RTStructure Niis Generated for  OPC-00014
# !!!!! No engough data for  OPC-00271
# Img and RTStructure Niis Generated for  OPC-00176
# Img and RTStructure Niis Generated for  OPC-00371
# Img and RTStructure Niis Generated for  OPC-00028
# Img and RTStructure Niis Generated for  OPC-00324
# Img and RTStructure Niis Generated for  OPC-00491
# Img and RTStructure Niis Generated for  OPC-00081
# Img and RTStructure Niis Generated for  OPC-00449
# Img and RTStructure Niis Generated for  OPC-00560
# Img and RTStructure Niis Generated for  OPC-00380
# Img and RTStructure Niis Generated for  OPC-00147
# Img and RTStructure Niis Generated for  OPC-00541
# Img and RTStructure Niis Generated for  OPC-00579
# Img and RTStructure Niis Generated for  OPC-00043
# Img and RTStructure Niis Generated for  OPC-00328
# Img and RTStructure Niis Generated for  OPC-00211
# Img and RTStructure Niis Generated for  OPC-00031
# Img and RTStructure Niis Generated for  OPC-00192
# Img and RTStructure Niis Generated for  OPC-00289
# Img and RTStructure Niis Generated for  OPC-00408
# Img and RTStructure Niis Generated for  OPC-00568
# Img and RTStructure Niis Generated for  OPC-00015
# Img and RTStructure Niis Generated for  OPC-00439
# Img and RTStructure Niis Generated for  OPC-00117
# Img and RTStructure Niis Generated for  OPC-00118
# Img and RTStructure Niis Generated for  OPC-00606
# Img and RTStructure Niis Generated for  OPC-00547
# Img and RTStructure Niis Generated for  OPC-00497
# Img and RTStructure Niis Generated for  OPC-00444
# !!!!! No engough data for  OPC-00354
# !!!!! No engough data for  OPC-00264
# Img and RTStructure Niis Generated for  OPC-00379
# Img and RTStructure Niis Generated for  OPC-00396
# Img and RTStructure Niis Generated for  OPC-00102
# Img and RTStructure Niis Generated for  OPC-00270
# Img and RTStructure Niis Generated for  OPC-00414
# Img and RTStructure Niis Generated for  OPC-00474
# Img and RTStructure Niis Generated for  OPC-00401
# Img and RTStructure Niis Generated for  OPC-00050
# Img and RTStructure Niis Generated for  OPC-00483
# Img and RTStructure Niis Generated for  OPC-00399
# Img and RTStructure Niis Generated for  OPC-00207
# Img and RTStructure Niis Generated for  OPC-00256
# Img and RTStructure Niis Generated for  OPC-00493
# Img and RTStructure Niis Generated for  OPC-00455
# Img and RTStructure Niis Generated for  OPC-00424
# Img and RTStructure Niis Generated for  OPC-00488
# Img and RTStructure Niis Generated for  OPC-00019
# Img and RTStructure Niis Generated for  OPC-00302
# Img and RTStructure Niis Generated for  OPC-00336
# Img and RTStructure Niis Generated for  OPC-00122

# %%
savedPatients = os.listdir(savePath)
len(savedPatients)
# Out:
# 597

# %% [markdown]
# ### 2. Figure out how many patient data are available

# %%
missing_gtv = []
missing_img = []
for p in savedPatients:
    path = os.path.join(savePath, p)
    files = os.listdir(path)

    if 'image.nii.gz' in files:
        if 'mask_GTV.nii.gz' in files:
            continue
        else:
            missing_gtv.append(p)
            print('This patient dosen\'t have GTV', p)
            
    else:
        missing_img.append(p)
        print('This patient dosen\'t have img', p)
# Out:
# This patient dosen't have GTV OPC-00502
# This patient dosen't have GTV OPC-00522
# This patient dosen't have GTV OPC-00094
# This patient dosen't have GTV OPC-00478
# This patient dosen't have GTV OPC-00175
# This patient dosen't have GTV OPC-00484
# This patient dosen't have GTV OPC-00278
# This patient dosen't have GTV OPC-00365
# This patient dosen't have GTV OPC-00221
# This patient dosen't have GTV OPC-00206
# This patient dosen't have GTV OPC-00183
# This patient dosen't have GTV OPC-00095
# This patient dosen't have GTV OPC-00374
# This patient dosen't have GTV OPC-00187
# This patient dosen't have GTV OPC-00571
# This patient dosen't have GTV OPC-00457
# This patient dosen't have GTV OPC-00479
# This patient dosen't have GTV OPC-00342
# This patient dosen't have GTV OPC-00430
# This patient dosen't have GTV OPC-00101
# This patient dosen't have GTV OPC-00191
# This patient dosen't have GTV OPC-00340
# This patient dosen't have GTV OPC-00330
# This patient dosen't have GTV OPC-00220
# This patient dosen't have GTV OPC-00369
# This patient dosen't have GTV OPC-00156
# This patient dosen't have GTV OPC-00030
# This patient dosen't have GTV OPC-00084
# This patient dosen't have GTV OPC-00229
# This patient dosen't have GTV OPC-00124
# This patient dosen't have GTV OPC-00582
# This patient dosen't have GTV OPC-00370
# This patient dosen't have GTV OPC-00573
# This patient dosen't have GTV OPC-00476
# This patient dosen't have GTV OPC-00131
# This patient dosen't have GTV OPC-00006
# This patient dosen't have GTV OPC-00138
# This patient dosen't have GTV OPC-00403
# This patient dosen't have GTV OPC-00351
# This patient dosen't have GTV OPC-00009
# This patient dosen't have GTV OPC-00433
# This patient dosen't have GTV OPC-00072
# This patient dosen't have GTV OPC-00021
# This patient dosen't have GTV OPC-00434
# This patient dosen't have GTV OPC-00284
# This patient dosen't have GTV OPC-00316
# This patient dosen't have GTV OPC-00575
# This patient dosen't have GTV OPC-00227
# This patient dosen't have GTV OPC-00180
# This patient dosen't have GTV OPC-00384
# This patient dosen't have GTV OPC-00242
# This patient dosen't have GTV OPC-00007
# This patient dosen't have GTV OPC-00464
# This patient dosen't have GTV OPC-00267
# This patient dosen't have GTV OPC-00295
# This patient dosen't have GTV OPC-00565
# This patient dosen't have GTV OPC-00247
# This patient dosen't have GTV OPC-00181
# This patient dosen't have GTV OPC-00470
# This patient dosen't have GTV OPC-00053
# This patient dosen't have GTV OPC-00003
# This patient dosen't have GTV OPC-00367
# This patient dosen't have GTV OPC-00173
# This patient dosen't have GTV OPC-00203
# This patient dosen't have GTV OPC-00262
# This patient dosen't have GTV OPC-00286
# This patient dosen't have GTV OPC-00023
# This patient dosen't have GTV OPC-00239
# This patient dosen't have GTV OPC-00532
# This patient dosen't have GTV OPC-00176
# This patient dosen't have GTV OPC-00028
# This patient dosen't have GTV OPC-00324
# This patient dosen't have GTV OPC-00560
# This patient dosen't have GTV OPC-00147
# This patient dosen't have GTV OPC-00328
# This patient dosen't have GTV OPC-00192
# This patient dosen't have GTV OPC-00015
# This patient dosen't have GTV OPC-00117
# This patient dosen't have GTV OPC-00606
# This patient dosen't have GTV OPC-00379
# This patient dosen't have GTV OPC-00396
# This patient dosen't have GTV OPC-00270
# This patient dosen't have GTV OPC-00399
# This patient dosen't have GTV OPC-00493
# This patient dosen't have GTV OPC-00336

# %%
len(missing_gtv) # actually, for most of these patients, they have data but they don't have gtvp, we can use empty image (0 image) for them
# Out:
# 85

# %%
len(missing_img)
# Out:
# 0

# %%
avaliable_patient = list(set(savedPatients) - set(missing_gtv))
len(avaliable_patient)
# Out:
# 512

# %% [markdown]
# ### 3. Resampling

# %%
from pathlib import Path
from multiprocessing import Pool
import logging

import click
import pandas as pd
import numpy as np
import SimpleITK as sitk

# %%
resample_path = '../../data/OPC_Radiomics/OPC-Radiomics-Nii-resample/'
if not os.path.exists(resample_path):
   os.makedirs(resample_path)

# %%
resampler = sitk.ResampleImageFilter()
resampler.SetOutputDirection([1, 0, 0, 0, 1, 0, 0, 0, 1])
resampling = [2,2,2] # mm
resampler.SetOutputSpacing(resampling)

# %%
def get_bouding_boxes(ct, pt):
    """
    Get the bounding boxes of the CT and PT images.
    This works since all images have the same direction
    """

    ct_origin = np.array(ct.GetOrigin())
    pt_origin = np.array(pt.GetOrigin())

    ct_position_max = ct_origin + np.array(ct.GetSize()) * np.array(
        ct.GetSpacing())
    pt_position_max = pt_origin + np.array(pt.GetSize()) * np.array(
        pt.GetSpacing())
    return np.concatenate(
        [
            np.maximum(ct_origin, pt_origin),
            np.minimum(ct_position_max, pt_position_max),
        ],
        axis=0,
    )

# %%
def resample_one_patient(p):
    savePath = '../../data/OPC_Radiomics/OPC-Radiomics-Nii/' # change it to wherever you need
    resample_path = '../../data/OPC_Radiomics/OPC-Radiomics-Nii-resample/' # change it to wherever you need to save the resampled data
    
    ct = sitk.ReadImage(os.path.join(savePath, p, 'image.nii.gz'))
    label = sitk.ReadImage(os.path.join(savePath, p, 'mask_GTV.nii.gz'))
    bb = get_bouding_boxes(ct, ct)
    size = np.round((bb[3:] - bb[:3]) / resampling).astype(int)
    resampler.SetOutputOrigin(bb[:3])
    resampler.SetSize([int(k) for k in size])  # sitk is so stupid
    resampler.SetInterpolator(sitk.sitkBSpline)
    ct = resampler.Execute(ct)
    sitk.WriteImage(ct, os.path.join(resample_path, p+'_image.nii.gz'))
    resampler.SetInterpolator(sitk.sitkNearestNeighbor)
    label = resampler.Execute(label)
    sitk.WriteImage(label, os.path.join(resample_path, p+'_mask_GTV.nii.gz'))

# %%
for p in avaliable_patient:
    resample_one_patient(p)

# %% [markdown]
# ### 4. Cropping

# %%
def find_centroid(mask):

    stats = sitk.LabelShapeStatisticsImageFilter()
    stats.Execute(mask)
    try:
        centroid_coords = stats.GetCentroid(255)
    except:
        print('Something wrong')
    centroid_idx = mask.TransformPhysicalPointToIndex(centroid_coords)

    return np.asarray(centroid_idx, dtype=np.float64)

# %%
crop_path = '../../data/OPC_Radiomics/OPC-Radiomics-Nii-resample-crop/' # the final data you are going to use in our model
if not os.path.exists(crop_path):
   os.makedirs(crop_path)

# %%
for p in avaliable_patient:
    
    image = sitk.ReadImage(os.path.join(resample_path, p+'_image.nii.gz'))
    mask = sitk.ReadImage(os.path.join(resample_path, p+'_mask_GTV.nii.gz'))

    patch_size = np.array([80,80,48])

    #crop the image to patch_size around the tumor center
    tumour_center = find_centroid(mask) # center of GTV
    size = patch_size
    min_coords = np.floor(tumour_center - size / 2).astype(np.int64)
    max_coords = np.floor(tumour_center + size / 2).astype(np.int64)
    min_x, min_y, min_z = min_coords
    max_x, max_y, max_z = max_coords
    image = image[min_x:max_x, min_y:max_y, min_z:max_z]

    # window image intensities to [-500, 1000] HU range
    image = sitk.Clamp(image, sitk.sitkFloat32, -500, 500)
    mask = mask[min_x:max_x, min_y:max_y, min_z:max_z]

    sitk.WriteImage(image, os.path.join(crop_path, p+'_image.nii.gz'))
    sitk.WriteImage(mask, os.path.join(crop_path, p+'_mask_GTV.nii.gz'))

# %%
import csv

with open('avaliable_patient.csv','w') as result_file:
    wr = csv.writer(result_file, dialect='excel')
    for p in avaliable_patient:
        wr.writerow([p])
